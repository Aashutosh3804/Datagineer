# %%
import pandas as pd
from sklearn.cluster import DBSCAN,KMeans
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA as sklearnPCA

# %%
data=pd.read_excel("./Instant Raw Report (11).xlsx")
data2=pd.read_excel("./Load Survey Data (6).xlsx")

# %%
data.columns
# Out:
# Index(['CCMS ID', 'Timestamp', 'Active Power kW', 'Apparent Power kVA',
#        'Current R (A)', 'Current Y (A)', 'Current B (A)', 'Voltage R (V)',
#        'Voltage Y (V)', 'Voltage B (V)', 'Total PF', 'Frequency (Hz)',
#        'MD kVA', 'MD kW', 'Load Relay Status R', 'Load Relay Status Y',
#        'Load Relay Status B', 'R Phase kW', 'Y Phase kW', 'B Phase kW',
#        'Active Mode', 'Total Active Energy', 'Total Apparent Energy',
#        'Current Day kWh', 'Current Day kVAh', 'Power On Time(Hrs)',
#        'Relay on Time(Hrs)', 'Current Day Meter on Period',
#        'Current Day Relay on Period'],
#       dtype='object')

# %%
data1=data[['Current R (A)','Current Y (A)','Current B (A)','Voltage R (V)','Voltage Y (V)','Voltage B (V)','Active Power kW', 'Apparent Power kVA']]

# %%
data1.head(5)
# Out:
#    Current R (A)  Current Y (A)  Current B (A)  Voltage R (V)  Voltage Y (V)  \
# 0          10.66           5.47           5.85         233.48         234.57
# 1          10.65           5.48           5.83         233.56         234.34
# 2          10.74           5.52           5.89         231.74         232.72
# 3          10.73           5.53           5.90         232.01         233.22
# 4          10.79           5.55           5.92         233.17         234.27
#
#    Voltage B (V)  Active Power kW  Apparent Power kVA
# 0         235.40             5.11                5.15
# 1         235.45             5.11                5.14
# 2         233.72             5.11                5.14
# 3         234.14             5.12                5.16
# 4         235.16             5.17                5.22

# %%
data2.head()
# Out:
#            CCMS ID            Timestamp    KWh   KVAh  Vr (Volt)  Vy (Volt)  \
# 0  SMR03-0219-0252  2019-05-01 23:00:00  2.732  2.752     233.23     234.30
# 1  SMR03-0219-0252  2019-05-01 22:00:00  5.108  5.143     236.64     238.00
# 2  SMR03-0219-0252  2019-05-01 21:00:00  5.120  5.156     237.01     238.69
# 3  SMR03-0219-0252  2019-05-01 20:00:00  4.985  5.025     237.29     238.79
# 4  SMR03-0219-0252  2019-05-01 19:00:00  0.372  0.375     244.08     245.06
#
#    Vb (Volt)  Ir (Amp)  Iy (Amp)  Ib (Amp)  Freq (Hz)   PF Total  Total Load
# 0     235.21     10.31      5.41      5.79      50.08  0.955  Ld        5.17
# 1     238.73     10.53      5.40      5.78      50.08  0.987  Ld        5.17
# 2     239.36     10.54      5.40      5.79      50.10  0.987  Ld        5.17
# 3     239.56      9.71      5.42      5.79      50.07  0.985  Ld        5.17
# 4     245.75      0.52      0.26      0.26      50.24  0.87  Lag        5.17

# %%
data2=data2.drop(labels=['CCMS ID','Total Load','Freq (Hz)','Timestamp','PF Total'],axis=1)

# %%
data2.head(5)
# Out:
#      KWh   KVAh  Vr (Volt)  Vy (Volt)  Vb (Volt)  Ir (Amp)  Iy (Amp)  Ib (Amp)
# 0  2.732  2.752     233.23     234.30     235.21     10.31      5.41      5.79
# 1  5.108  5.143     236.64     238.00     238.73     10.53      5.40      5.78
# 2  5.120  5.156     237.01     238.69     239.36     10.54      5.40      5.79
# 3  4.985  5.025     237.29     238.79     239.56      9.71      5.42      5.79
# 4  0.372  0.375     244.08     245.06     245.75      0.52      0.26      0.26

# %%
clustering =KMeans(2)
clustering.fit(pca_data)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
# Out:
# array([-43, -44, -42, -41, -40, -39, -38, -37, -36, -35, -34, -33],
#       dtype=int64)

# %%
clustering.labels_
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
 from sklearn.decomposition import PCA 
  
pca = PCA(3) 
pca.fit(data1) 
  
pca_data = pd.DataFrame(pca.transform(data1)) 
  
print(pca_data.head())
# Out:
#            0         1         2
# 0  -8.777696  7.843453  2.407525
# 1  -8.836164  7.814529  2.450737
# 2 -11.814773  7.725992  2.384804
# 3 -11.125678  7.787615  2.394704
# 4  -9.277977  7.998148  2.445238

# %%
clustering
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=2, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
from matplotlib import colors as mcolors 
import math 

''' Generating different colors in ascending order 
								of their hsv values '''
colors = list(zip(*sorted(( 
					tuple(mcolors.rgb_to_hsv( 
						mcolors.to_rgba(color)[:3])), name) 
					for name, color in dict( 
							mcolors.BASE_COLORS, **mcolors.CSS4_COLORS 
													).items())))[1] 


# number of steps to taken generate n(clusters) colors 
skips = math.floor(len(colors[5 : -5])/3) 
cluster_colors = colors[5 : -5 : skips]

# %%
from mpl_toolkits.mplot3d import Axes3D 
import matplotlib.pyplot as plt 

fig = plt.figure() 
ax = fig.add_subplot(111, projection = '3d') 
ax.scatter(pca_data[0], pca_data[1], pca_data[2], 
		c = list(map(lambda label : cluster_colors[label], 
											clustering.labels_))) 

str_labels = list(map(lambda label:'% s' % label, clustering.labels_)) 

list(map(lambda data1, data2, data3, str_label: 
		ax.text(data1, data2, data3, s = str_label, size = 16.5, 
		zorder = 20, color = 'k'), pca_data[0], pca_data[1], 
		pca_data[2], str_labels)) 

plt.show()

# %%
y_kmeans = clustering.predict(pca_data)

# %%
from sklearn.datasets.samples_generator import make_blobs

# %%
plt.scatter(pca_data.values[:, 0], pca_data.values[:, 1], c=y_kmeans, s=50, cmap='viridis')

# %%
# Out:
# (742, 2)

# %%
import seaborn as sn

# %%
data.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000015A3C541DD8>,
# ...
#       dtype=object)
